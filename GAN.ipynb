# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# Generator
class Generator(nn.Module):
    def __init__(self, noise_dim):
        super(Generator, self).__init__()
        self.noise_dim = noise_dim
        self.main = nn.Sequential(
            nn.Linear(noise_dim, 7 * 7 * 256),
            nn.ReLU(True),
            nn.Unflatten(1, (256, 7, 7)),
            nn.ConvTranspose2d(256, 128, 5, stride=1, padding=2),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, 5, stride=2, padding=2, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 1, 5, stride=2, padding=2, output_padding=1),
            nn.Tanh()
        )

    def forward(self, x):
        return self.main(x)


# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(1, 64, 5, stride=2, padding=2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 128, 5, stride=2, padding=2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.BatchNorm2d(128),
            nn.Flatten(),
            nn.Linear(7 * 7 * 128, 1)
        )

    def forward(self, x):
        return self.main(x)


# Noise dimension
NOISE_DIM = 100

# Generator and discriminator
generator = Generator(NOISE_DIM)
discriminator = Discriminator()

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
generator = generator.to(device)
discriminator = discriminator.to(device)

# Loss function
criterion = nn.BCEWithLogitsLoss()

# Optimizers
generator_optimizer = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
discriminator_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Training hyperparameters
NUM_EPOCHS = 50
BATCH_SIZE = 256

# DataLoader
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

# Training loop
for epoch in range(NUM_EPOCHS):
    for i, data in enumerate(train_loader):
        real_images, _ = data
        real_images = real_images.to(device)

        # Train discriminator with real images
        discriminator_optimizer.zero_grad()
        real_labels = torch.ones(real_images.size(0), 1, device=device)
        real_outputs = discriminator(real_images)
        real_loss = criterion(real_outputs, real_labels)
        real_loss.backward()

        # Train discriminator with fake images
        noise = torch.randn(real_images.size(0), NOISE_DIM, device=device)
        fake_images = generator(noise)
        fake_labels = torch.zeros(real_images.size(0), 1, device=device)
        fake_outputs = discriminator(fake_images.detach())
        fake_loss = criterion(fake_outputs, fake_labels)
        fake_loss.backward()
        discriminator_optimizer.step()

        # Train generator
        generator_optimizer.zero_grad()
        fake_labels = torch.ones(real_images.size(0), 1, device=device)
        fake_outputs = discriminator(fake_images)
        gen_loss = criterion(fake_outputs, fake_labels)
        gen_loss.backward()
        generator_optimizer.step()

        # Print losses
        if i % 100 == 0:
            print(f'Epoch [{epoch+1}/{NUM_EPOCHS}], Step [{i+1}/{len(train_loader)}], '
                  f'Discriminator Loss: {real_loss.item() + fake_loss.item():.4f}, '
                  f'Generator Loss: {gen_loss.item():.4f}')
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:11<00:00, 898592.56it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 135019.03it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1269700.34it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4039552.33it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Epoch [1/50], Step [1/235], Discriminator Loss: 1.5818, Generator Loss: 1.1485
# Epoch [1/50], Step [101/235], Discriminator Loss: 0.2071, Generator Loss: 4.0171
# Epoch [1/50], Step [201/235], Discriminator Loss: 0.0701, Generator Loss: 4.2348
# Epoch [2/50], Step [1/235], Discriminator Loss: 0.0478, Generator Loss: 4.4773
# Epoch [2/50], Step [101/235], Discriminator Loss: 0.0118, Generator Loss: 5.1833
# Epoch [2/50], Step [201/235], Discriminator Loss: 0.0224, Generator Loss: 5.0885
# Epoch [3/50], Step [1/235], Discriminator Loss: 0.0407, Generator Loss: 5.0218
# Epoch [3/50], Step [101/235], Discriminator Loss: 0.0432, Generator Loss: 5.0046
# Epoch [3/50], Step [201/235], Discriminator Loss: 0.0086, Generator Loss: 5.4666
# Epoch [4/50], Step [1/235], Discriminator Loss: 0.0113, Generator Loss: 5.7475
# Epoch [4/50], Step [101/235], Discriminator Loss: 0.0265, Generator Loss: 5.5772
# Epoch [4/50], Step [201/235], Discriminator Loss: 0.0209, Generator Loss: 5.9935
# Epoch [5/50], Step [1/235], Discriminator Loss: 0.0055, Generator Loss: 6.4696
# Epoch [17/50], Step [101/235], Discriminator Loss: 0.9535, Generator Loss: 4.1791
# Epoch [17/50], Step [201/235], Discriminator Loss: 0.7724, Generator Loss: 0.6324
# Epoch [18/50], Step [1/235], Discriminator Loss: 0.4715, Generator Loss: 1.6988
# Epoch [18/50], Step [101/235], Discriminator Loss: 0.5774, Generator Loss: 1.1552
# Epoch [18/50], Step [201/235], Discriminator Loss: 1.1999, Generator Loss: 4.4509
# Epoch [19/50], Step [1/235], Discriminator Loss: 0.3810, Generator Loss: 2.0763
# Epoch [19/50], Step [101/235], Discriminator Loss: 0.3897, Generator Loss: 2.3189
# Epoch [19/50], Step [201/235], Discriminator Loss: 0.3994, Generator Loss: 1.6610
# Epoch [20/50], Step [1/235], Discriminator Loss: 0.4201, Generator Loss: 1.4926
# Epoch [20/50], Step [101/235], Discriminator Loss: 0.4000, Generator Loss: 2.8820
# Epoch [20/50], Step [201/235], Discriminator Loss: 0.4720, Generator Loss: 1.5541
# Epoch [21/50], Step [1/235], Discriminator Loss: 0.5592, Generator Loss: 0.7888
# Epoch [21/50], Step [101/235], Discriminator Loss: 0.3541, Generator Loss: 2.1439
# Epoch [21/50], Step [201/235], Discriminator Loss: 0.4736, Generator Loss: 2.0423
# Epoch [22/50], Step [1/235], Discriminator Loss: 0.6665, Generator Loss: 0.7909
# Epoch [22/50], Step [101/235], Discriminator Loss: 0.4823, Generator Loss: 1.6337
# Epoch [22/50], Step [201/235], Discriminator Loss: 0.4311, Generator Loss: 1.8462
# Epoch [23/50], Step [1/235], Discriminator Loss: 0.3942, Generator Loss: 1.9659
# Epoch [23/50], Step [101/235], Discriminator Loss: 0.5288, Generator Loss: 1.1036
# Epoch [23/50], Step [201/235], Discriminator Loss: 0.3964, Generator Loss: 2.6195
# Epoch [24/50], Step [1/235], Discriminator Loss: 0.3955, Generator Loss: 2.6977
# Epoch [24/50], Step [101/235], Discriminator Loss: 0.5387, Generator Loss: 3.1137
# Epoch [24/50], Step [201/235], Discriminator Loss: 0.5213, Generator Loss: 3.2335
# Epoch [25/50], Step [1/235], Discriminator Loss: 0.6206, Generator Loss: 3.5416
# Epoch [25/50], Step [101/235], Discriminator Loss: 0.4727, Generator Loss: 1.5576
# Epoch [25/50], Step [201/235], Discriminator Loss: 2.3644, Generator Loss: 0.5542
# Epoch [26/50], Step [1/235], Discriminator Loss: 0.4102, Generator Loss: 3.3906
# Epoch [26/50], Step [101/235], Discriminator Loss: 0.5685, Generator Loss: 3.4900
# Epoch [26/50], Step [201/235], Discriminator Loss: 0.4622, Generator Loss: 2.9193
# Epoch [27/50], Step [1/235], Discriminator Loss: 0.5382, Generator Loss: 3.2324
# Epoch [27/50], Step [101/235], Discriminator Loss: 0.7290, Generator Loss: 0.8063
# Epoch [27/50], Step [201/235], Discriminator Loss: 0.3938, Generator Loss: 2.2687
# Epoch [28/50], Step [1/235], Discriminator Loss: 0.4739, Generator Loss: 2.3631
# Epoch [28/50], Step [101/235], Discriminator Loss: 0.3985, Generator Loss: 3.1939
# Epoch [28/50], Step [201/235], Discriminator Loss: 0.3517, Generator Loss: 3.8254
# Epoch [29/50], Step [1/235], Discriminator Loss: 1.1974, Generator Loss: 5.3596
# Epoch [41/50], Step [1/235], Discriminator Loss: 0.3245, Generator Loss: 2.2371
# Epoch [41/50], Step [101/235], Discriminator Loss: 0.5317, Generator Loss: 1.9828
# Epoch [41/50], Step [201/235], Discriminator Loss: 0.4182, Generator Loss: 3.3800
# Epoch [42/50], Step [1/235], Discriminator Loss: 0.3853, Generator Loss: 3.0332
# Epoch [42/50], Step [101/235], Discriminator Loss: 0.5390, Generator Loss: 3.5082
# Epoch [42/50], Step [201/235], Discriminator Loss: 0.4058, Generator Loss: 2.2233
# Epoch [43/50], Step [1/235], Discriminator Loss: 2.1277, Generator Loss: 5.3913
# Epoch [43/50], Step [101/235], Discriminator Loss: 0.6207, Generator Loss: 4.9274
# Epoch [43/50], Step [201/235], Discriminator Loss: 0.6150, Generator Loss: 1.4342
# Epoch [44/50], Step [1/235], Discriminator Loss: 0.3459, Generator Loss: 3.1603
# Epoch [44/50], Step [101/235], Discriminator Loss: 1.6355, Generator Loss: 9.6580
# Epoch [44/50], Step [201/235], Discriminator Loss: 0.5200, Generator Loss: 2.0634
# Epoch [45/50], Step [1/235], Discriminator Loss: 0.3604, Generator Loss: 3.3089
# Epoch [45/50], Step [101/235], Discriminator Loss: 0.4249, Generator Loss: 3.2804
# Epoch [45/50], Step [201/235], Discriminator Loss: 0.3197, Generator Loss: 2.8071
# Epoch [46/50], Step [1/235], Discriminator Loss: 0.3159, Generator Loss: 1.7464
# Epoch [46/50], Step [101/235], Discriminator Loss: 0.6098, Generator Loss: 1.6047
# Epoch [46/50], Step [201/235], Discriminator Loss: 0.4328, Generator Loss: 2.8220
# Epoch [47/50], Step [1/235], Discriminator Loss: 1.0471, Generator Loss: 5.5026
# Epoch [47/50], Step [101/235], Discriminator Loss: 0.8480, Generator Loss: 0.6545
# Epoch [47/50], Step [201/235], Discriminator Loss: 1.6990, Generator Loss: 5.2774
# Epoch [48/50], Step [1/235], Discriminator Loss: 0.3619, Generator Loss: 2.5046
# Epoch [48/50], Step [101/235], Discriminator Loss: 0.4702, Generator Loss: 1.3659
# Epoch [48/50], Step [201/235], Discriminator Loss: 0.3659, Generator Loss: 2.1331
# Epoch [49/50], Step [1/235], Discriminator Loss: 0.3584, Generator Loss: 3.2264
# Epoch [49/50], Step [101/235], Discriminator Loss: 0.5555, Generator Loss: 1.3175
# Epoch [49/50], Step [201/235], Discriminator Loss: 0.3107, Generator Loss: 2.3315
# Epoch [50/50], Step [1/235], Discriminator Loss: 0.3337, Generator Loss: 2.1456
# Epoch [50/50], Step [101/235], Discriminator Loss: 0.3238, Generator Loss: 2.6217
# Epoch [50/50], Step [201/235], Discriminator Loss: 0.2729, Generator Loss: 2.7175

# %%
# Generate and save images
def generate_and_save_images(model, epoch, noise):
    model.eval()
    with torch.no_grad():
        fake_images = model(noise).cpu()
        fake_images = fake_images.view(fake_images.size(0), 28, 28)

        fig = plt.figure(figsize=(4, 4))
        for i in range(fake_images.size(0)):
            plt.subplot(4, 4, i+1)
            plt.imshow(fake_images[i], cmap='gray')
            plt.axis('off')

        plt.savefig(f'image_at_epoch_{epoch+1:04d}.png')
        plt.show()

# Generate test noise
test_noise = torch.randn(16, NOISE_DIM, device=device)
generate_and_save_images(generator, NUM_EPOCHS, test_noise)
